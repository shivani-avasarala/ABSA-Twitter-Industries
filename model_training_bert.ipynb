# %%
import pandas as pd
import numpy as np
import torch
import transformers as tfm
import spacy

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# Load the English stopwords
stopwords = set(stopwords.words('english'))

# Load the news category dataset
df = pd.read_json('/content/Sample_News_Category.json', lines=True)

# Preprocess the text data
df['text'] = df['headline'] + ". " + df['short_description']
df['text'] = df['text'].str.lower()
df['text'] = df['text'].str.replace('[^\w\s]','')
df['text'] = df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# Extract aspects using spaCy
nlp = spacy.load("en_core_web_sm")
df['aspects'] = df['text'].apply(lambda x: [chunk.text for chunk in nlp(x).noun_chunks])

# Tokenize the text using BERT
tokenizer = tfm.BertTokenizer.from_pretrained('bert-base-uncased')
encoded_data = tokenizer.batch_encode_plus(
    df['text'].values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    padding=True, 
    truncation=True,
    max_length=256, 
    return_tensors='pt'
)

# Load the pre-trained BERT model
model = tfm.BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
optimizer = tfm.AdamW(model.parameters(), lr=2e-5, eps=1e-8)

# Predict the sentiment for each aspect
sentiments = []
for i, row in df.iterrows():
    aspects = row['aspects']
    text = row['text']
    input_ids = encoded_data['input_ids'][i]
    attention_mask = encoded_data['attention_mask'][i]
    aspect_sentiments = []
    for aspect in aspects:
        aspect_tokens = tokenizer.tokenize(aspect)
        aspect_ids = tokenizer.convert_tokens_to_ids(aspect_tokens)
        aspect_ids = torch.tensor(aspect_ids).unsqueeze(0)
        aspect_mask = torch.ones_like(aspect_ids)
        with torch.no_grad():
            outputs = model(aspect_ids, attention_mask=aspect_mask)
            logits = outputs[0]
            sentiment = np.argmax(logits.detach().numpy())
            aspect_sentiments.append(sentiment)
    overall_sentiment = np.mean(aspect_sentiments)
    sentiments.append(overall_sentiment)

# Add the sentiments to the DataFrame
df['sentiment'] = sentiments
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# <ipython-input-3-c3c74d304d99>:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['text'] = df['text'].str.replace('[^\w\s]','')
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
for item in df['aspects']:

  print(item)
# Out:
# ['4 million americans', 'sleeves', 'covid boosters health experts', 'demand', '171 million doses', 'us', 'fall']
# ['american airlines flyer', 'banned life punching flight attendant video subdued passengers crew', 'back aircraft confrontation', 'us attorneys office los angeles']
# ['23 funniest tweets cats dogs', '1723 dog']
# ['funniest tweets parents', 'grownup toothpaste toddlers', 'toothbrush', 'teeth carolina reaper', 'tabasco sauce']
# ['woman', 'cops', 'black birdwatcher', 'lawsuit exemployer amy cooper', 'investment firm franklin templeton', 'branding racist video central park encounter']
# ['cleaner dead belk bathroom 4 days body', 'police 63yearold woman', 'south carolina store', 'dead monday family', 'missing authorities']
# ['reporter', 'adorable surprise boyfriend', 'live tv', 'who', 'anchor new yorks pix11', 'journalist michelle ross']
# ['puerto ricans', 'water hurricane fionas', 'half million people', 'water service', 'three days storm', 'us territory']
# ['complexity child immigrants mija director isabel castro combined music documentaries style euphoria clueless tell nuanced immigration story']
# ['biden un call russian war affront bodys charter white house officials', 'crux presidents', 'condemnation', 'russia', 'brutal war']
# ['world cup captains', 'rainbow armbands qatar fifa', 'pressure', 'several european soccer federations', 'human rights campaign discrimination world cup']
# ['man', 'fire apparent protest funeral japans', 'abe incident', 'growing wave protests funeral shinzo', 'one divisive leaders postwar japanese politics']
# ['fiona', 'bermuda hurricane fiona', 'turks', 'caicos islands forecast', 'past bermuda']
# ['twitch', 'gambling sites streamer scams folks', '200000 one mans claims', 'people platform', 'several popular streamers', 'twitch boycott']
# ['virginia thomas', 'interview', 'jan', '6 panel conservative activist virginia thomas wife supreme court justice clarence thomas', 'voluntary interview house panel', 'jan 6 insurrection']
# ['russian cosmonaut valery polyakov', 'record', 'space', 'trip', 'outer space', 'orbit earth', '7075 times']
# ['reboot clever navelgazey look', 'tv reboots', 'keeganmichael key judy greer johnny knoxville hulu show', 'revival fictional early 2000s sitcom']
# ['maury', 'basestealing shortstop dodgers', '89 maury wills', 'los angeles dodgers', 'three world series titles basestealing prowess']
# ['russia', 'kremlinbacked efforts', 'four regions', 'stage', 'moscow', 'war']
# ['fiona barrels', 'turks caicos islands', 'category 3 hurricane turks caicos islands government', 'curfew intensifying storm', 'copious rain dominican republic puerto rico']
# ['golden globes', 'offair', '18 months', 'hollywood', 'hfpas 87 members nonamerican journalists', 'black members']
# ['biden', 'us forces', 'taiwan china', 'president issues vow tensions', 'china']
# ['hurricane fiona', 'dominican republic pounding puerto rico storm', 'power grid', 'unleashed floods', 'puerto rico governor']
# ['reno air race singleengine plane', 'participating national championship air races', 'field killing pilot officials']
# ['beautiful sad time', 'ukrainian cultural festival', 'deeper meaning year', 'annual celebration', 'different feel russias invasion']
# ['family american held afghanistan', 'freed taliban prisoner swap mark frerichs navy veteran civilian contractor', 'afghanistan']
# ['las vegas aces', 'first wnba title chelsea gray', 'mvp las vegas', 'never professional sports champion']
# ['world leaders', 'respects', 'queen elizabeth ii president joe biden first lady jill biden', 'thousands mourners locals tourists royals world leaders', 'respects']
# ['james cameron', 'clashed studio avatar release avatar director', '2009 movie', 'everything', 'that']
# ['french spiderman', '60th birthday massive skyscraper climb alain robert known french spiderman', 'burj khalifa empire state building']
# ['biden', 'queens', 'death', 'giant hole royal family us president joe biden london funeral queen elizabeth ii', 'heart', 'royal family', 'queens death', 'giant hole']
# ['watchdog report', 'census takers', '2020 data', 'false information work', 'census takers', 'bonuses office inspector general']
# ['first public global database fossil fuels', 'first public database fossil fuel production reserves emissions launches']
# ['man', 'mourners', 'waiting view queen', 'thames', 'bid', 'police']
# ['alaska prepares historiclevel storm', 'coast', '10 years people']
# ['puerto rico braces', 'severe flooding tropical storm fiona', 'puerto rico hurricane watch saturday storm', 'us territory']
# ['alarm disease floodhit areas pakistan world health organization', 'alarm', 'second disaster', 'deadly floods', 'pakistan summer doctors medical workers', 'race battle outbreaks waterborne diseases']
# ['privatization', 'answer', 'jacksons water crisis studies', 'ending public administration water supplies', 'that', 'table']
# ['german customs officials', 'trail slime', 'bags', 'giant snails', 'never history', 'duesseldorf customs office trail slime', 'us smuggled goods spokesman michael walk', 'media']
# ['blade runner 2099 limited series produced ridley scott director original 1982 film', 'writer 2017 sequel newest installment scifi franchise']
# ['bill help', 'afghans', 'taliban', 'long odds', 'senate republican outrage', 'shoddy us withdrawal afghanistan', 'support resettling refugees']
# ['alabama sidesteps compensation survivor', '63 kkk blast sarah collins rudolph', 'eye pieces glass', 'body', 'ku klux klan bombing', 'sister three black girls', 'alabama church']
# ['racism', 'root water crisis mississippi capital boilwater advisory', 'free bottled water']
# ['phantom opera', 'phantom opera broadways', 'longestrunning show', 'close february 2023 victim postpandemic softening theater attendance new york']
# ['complies justice dept subpoena report', 'former white house chief staff', 'records', 'part federal investigation']
# ['alex aster tiktoker', 'publishing industry', 'better colombianamerican authors', 'new book lightlark', 'readers']
# ['chickfila worker', 'woman baby', 'mykel gordon rushed womans aid', 'assailant police', 'first time gordon', 'life']
# ['viola davis', 'heart attack woman king']
# ['kim', 'next boyfriend', 'reality star', 'james corden', 'she', 'whatever', 'i']
# ['podcasters', '100k reward information', '2pacs', 'las vegas podcasters', 'rap icon']

# %%
for item in df['sentiment']:

  print(item)
# Out:
# 1.5714285714285714
# 1.5
# 2.0
# 1.4
# 1.6666666666666667
# 1.2
# 1.1666666666666667
# 1.0
# 2.0
# 1.4
# 1.6
# 1.4
# 1.4
# 1.6666666666666667
# 1.1666666666666667
# 1.7142857142857142
# 1.5
# 1.4
# 1.1666666666666667
# 1.8
# 1.3333333333333333
# 1.6
# 1.2
# 2.0
# 1.6
# 1.3333333333333333
# 1.25
# 1.6
# 1.8
# 1.6666666666666667
# 1.625
# 1.6666666666666667
# 1.5
# 1.3333333333333333
# 1.0
# 1.25
# 1.6666666666666667
# 1.3333333333333333
# 1.25
# 2.0
# 1.4285714285714286
# 1.5714285714285714
# 1.3333333333333333
# 1.75
# 1.5
# 1.4
# 1.8333333333333333
# 1.0
# 1.2857142857142858
# 1.6

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 71.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.1

# %%
for text in df['text']:

  print(text)
# Out:
# 4 million americans roll sleeves omicrontargeted covid boosters health experts said early predict whether demand would match 171 million doses new boosters us ordered fall
# american airlines flyer charged banned life punching flight attendant video subdued passengers crew fled back aircraft confrontation according us attorneys office los angeles
# 23 funniest tweets cats dogs week sept 1723 dog dont understand could eaten
# funniest tweets parents week sept 1723 accidentally put grownup toothpaste toddlers toothbrush screamed like cleaning teeth carolina reaper dipped tabasco sauce
# woman called cops black birdwatcher loses lawsuit exemployer amy cooper accused investment firm franklin templeton unfairly firing branding racist video central park encounter went viral
# cleaner dead belk bathroom 4 days body found police 63yearold woman seen working south carolina store thursday found dead monday family reported missing authorities said
# reporter gets adorable surprise boyfriend live tv whos behind anchor new yorks pix11 asked journalist michelle ross finished interview
# puerto ricans desperate water hurricane fionas rampage half million people remained without water service three days storm lashed us territory
# new documentary captures complexity child immigrants mija director isabel castro combined music documentaries style euphoria clueless tell nuanced immigration story
# biden un call russian war affront bodys charter white house officials say crux presidents visit un year fullthroated condemnation russia brutal war
# world cup captains want wear rainbow armbands qatar fifa come pressure several european soccer federations want support human rights campaign discrimination world cup
# man sets fire apparent protest funeral japans abe incident underscores growing wave protests funeral shinzo abe one divisive leaders postwar japanese politics
# fiona threatens become category 4 storm headed bermuda hurricane fiona lashed turks caicos islands forecast squeeze past bermuda later week
# twitch bans gambling sites streamer scams folks 200000 one mans claims scammed people platform caused several popular streamers consider twitch boycott
# virginia thomas agrees interview jan 6 panel conservative activist virginia thomas wife supreme court justice clarence thomas agreed participate voluntary interview house panel investigating jan 6 insurrection
# russian cosmonaut valery polyakov broke record 437day stay space dies 80 polyakovs recordbreaking trip outer space saw orbit earth 7075 times travel nearly 187 million miles
# reboot clever navelgazey look inside tv reboots starring keeganmichael key judy greer johnny knoxville hulu show follows revival fictional early 2000s sitcom
# maury wills basestealing shortstop dodgers dies 89 maury wills helped los angeles dodgers win three world series titles basestealing prowess died
